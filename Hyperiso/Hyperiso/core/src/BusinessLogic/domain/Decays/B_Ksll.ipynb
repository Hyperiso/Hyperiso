# %%
from sympy import *
m_B, m_K, q2, tp, tm, t0 = symbols('m_B m_{K^*} q^2 t_+ t_- t_0', real=True) 
A_1, A_12, V, T_1, T_2, T_23 = symbols('A_1 A_{12} V T_1 T_2 T_{23}', real=True)

# %%
A_2 = (pow(m_B+m_K,2)*(m_B*m_B-m_K*m_K-q2)*A_1-16*m_B*m_K*m_K*(m_B+m_K)*A_12)/((pow(m_B+m_K,2)-q2)*(pow(m_B-m_K,2)-q2))

# %%
stm = solve(tp * (1 - sqrt(1 - tm / tp)) - t0, tm)

# %%
tmB, tmK = solve([(m_B + m_K) ** 2 - tp, (m_B - m_K) ** 2 - stm[0]], (m_B, m_K))[0]
tmK
# Out:
# sqrt(t_+ + 2*t_0 - 2*sqrt(2*t_+*t_0 - t_0**2) - t_0**2/t_+)/2

# %%
A_2 = factor(A_2.subs({m_B: tmB, m_K: tmK}))

# %%
factor(expand(A_2).coeff(A_12))
# Out:
# 2*(-t_+ + t_0)**2*(-t_+ + sqrt(2*t_+*t_0 - t_0**2))/((q^2 - t_+)*(q^2*t_+ - 2*t_+*t_0 + t_0**2))

# %%
a_1, a_2, s_hat, u = symbols("a_1 a_2 \hat{s} u", real=True)

ubar = 1 - u
xi = 2 * u - 1
phi = 6 * u * ubar * (1 + 3 * a_1 * xi + a_2 * (-3 + 15 * xi ** 2) / 2)
f = simplify(phi / (3 * (ubar + s_hat * u)))

# %%
F_perp = poly(integrate(f, (u, 0, 1)), (a_1, a_2))
factor(F_perp.nth(1, 0))
# Out:
# -(\hat{s}**3 - 6*\hat{s}**2*log(\hat{s}) + 9*\hat{s}**2 - 6*\hat{s}*log(\hat{s}) - 9*\hat{s} - 1)/(\hat{s} - 1)**4

# %%
v = ubar + s_hat * u
x_perp = simplify(phi * (1 + v) / (3 * v ** 2))
u0 = symbols('u_0', positive=True)
X_perp = poly(integrate(x_perp, (u, 0, 1)), (a_1, a_2))
# X_perp = integrate(x_perp, (u, 0, 1))

# %%
factor(72 * s_hat ** 2 + 96 * s_hat + 12)
# Out:
# 12*(6*\hat{s}**2 + 8*\hat{s} + 1)

# %%
G3p = Matrix([[95, -10], [-16, 110]]) / 9
P, D = G3p.diagonalize()
simplify(P.inv())
# Out:
# Matrix([
# [ 16*sqrt(865)/865, 1/2 - 3*sqrt(865)/346],
# [-16*sqrt(865)/865, 3*sqrt(865)/346 + 1/2]])

# %%
a1p, a2p, z3a, z3v, w10a, dtp, dtm = symbols('a_1^\parallel a_2^\parallel \zeta_3^A \zeta_3^V \omega_{1\,0}^A \\tilde{\delta}_+ \\tilde{\delta}_-', real=True)

# %%
g_perp_a = 6 * u * ubar * (1 + a1p * xi + (a2p / 4 + 5 * z3a / 3 * (1 - 3 * w10a / 16)) * (5 * xi ** 2 - 1)) + 6 * dtp * (3 * u * ubar + ubar * ln(ubar) + u * ln(u)) + 6 * dtm * (ubar * ln(ubar) - u * ln(u))
g_perp_v = 3 * (1 + xi ** 2) / 4 + a1p * 3 * xi ** 3 / 2 + (3 * a2p / 7 + 5 * z3a) * (3 * xi ** 2 - 1) + (9 * a2p / 112 + 105 * z3v / 16 - 15 * z3a * w10a / 64) * (3 - 30 * xi **2 + 35 * xi ** 4) + 3 * dtp * (2 + ln(u) + ln(ubar)) / 2 + 3 * dtm / 2 * (2 * xi + ln(ubar) - ln(u))

g_perp_a_lt = 6 * u * ubar * (1 + a1p * xi + (a2p / 4 + 5 * z3a / 3 * (1 - 3 * w10a / 16)) * (5 * xi ** 2 - 1)) + 6 * dtp * (3 * u * ubar)
g_perp_v_lt = 3 * (1 + xi ** 2) / 4 + a1p * 3 * xi ** 3 / 2 + (3 * a2p / 7 + 5 * z3a) * (3 * xi ** 2 - 1) + (9 * a2p / 112 + 105 * z3v / 16 - 15 * z3a * w10a / 64) * (3 - 30 * xi ** 2 + 35 * xi ** 4) + 3 * dtp + 3 * dtm * xi

# %%
f = simplify(g_perp_v_lt - diff(g_perp_a, u) / 4)
f
# Out:
# -525*\omega_{1,0}^A*\zeta_3^A*u**4/4 + 225*\omega_{1,0}^A*\zeta_3^A*u**3 - 225*\omega_{1,0}^A*\zeta_3^A*u**2/2 + 15*\omega_{1,0}^A*\zeta_3^A*u + 9*\tilde{\delta}_+*u - 3*\tilde{\delta}_+*log(u)/2 + 3*\tilde{\delta}_+*log(1 - u)/2 - 3*\tilde{\delta}_+/2 + 6*\tilde{\delta}_-*u + 3*\tilde{\delta}_-*log(u)/2 + 3*\tilde{\delta}_-*log(1 - u)/2 + 200*\zeta_3^A*u**3 - 240*\zeta_3^A*u**2 + 60*\zeta_3^A*u + 3675*\zeta_3^V*u**4 - 7350*\zeta_3^V*u**3 + 4725*\zeta_3^V*u**2 - 1050*\zeta_3^V*u + 105*\zeta_3^V/2 + 12*a_1^\parallel*u**3 - 9*a_1^\parallel*u**2 + 45*a_2^\parallel*u**4 - 60*a_2^\parallel*u**3 + 18*a_2^\parallel*u**2 + 3*u**2

# %%
f_si = nsimplify((3./4.*(1.+pow(2.*u-1.,2.))+a1p*3./2.*pow(2.*u-1.,3.)+(3./7.*a2p+5.*z3a)*(3.*pow(2.*u-1.,2.)-1.)+(9./112.*a2p+105./16.*z3v-15./64.*z3a*w10a)*(3.-30.*pow(2.*u-1.,2.)+35.*pow(2.*u-1.,4.))+3.*dtp+3.*dtm*(2.*u-1.))-1./4.*(6.*(1.-2.*u)*(1.+a1p*(2.*u-1.)+(a2p/4.+5./3.*z3a*(1.-3./16.*w10a)+35./4.*z3v)*(5.*pow(2.*u-1.,2.)-1.))+6.*u*(1.-u)*(2.*a1p*u+(a2p/4.+5./3.*z3a*(1.-3./16.*w10a)+35./4.*z3v)*(20.*u*(2.*u-1.)))+18.*dtp*(1.-2.*u)-12.*dtm))
simplify(f_si)
# Out:
# -150*\omega_{1,0}^A*\zeta_3^A*u**4 + 2175*\omega_{1,0}^A*\zeta_3^A*u**3/8 - 150*\omega_{1,0}^A*\zeta_3^A*u**2 + 195*\omega_{1,0}^A*\zeta_3^A*u/8 + 9*\tilde{\delta}_+*u - 3*\tilde{\delta}_+/2 + 6*\tilde{\delta}_-*u + 100*\zeta_3^A*u**4 - 50*\zeta_3^A*u**3 - 40*\zeta_3^A*u**2 + 10*\zeta_3^A*u + 4200*\zeta_3^V*u**4 - 15225*\zeta_3^V*u**3/2 + 4200*\zeta_3^V*u**2 - 1365*\zeta_3^V*u/2 + 15*a_1^\parallel*u**3 - 15*a_1^\parallel*u**2 + 3*a_1^\parallel*u + 60*a_2^\parallel*u**4 - 195*a_2^\parallel*u**3/2 + 48*a_2^\parallel*u**2 - 15*a_2^\parallel*u/2 + 3*u**2

# %%
simplify(f_si - f)
# Out:
# -75*\omega_{1,0}^A*\zeta_3^A*u**4/4 + 375*\omega_{1,0}^A*\zeta_3^A*u**3/8 - 75*\omega_{1,0}^A*\zeta_3^A*u**2/2 + 75*\omega_{1,0}^A*\zeta_3^A*u/8 + 3*\tilde{\delta}_+*log(u)/2 - 3*\tilde{\delta}_+*log(1 - u)/2 - 3*\tilde{\delta}_-*log(u)/2 - 3*\tilde{\delta}_-*log(1 - u)/2 + 100*\zeta_3^A*u**4 - 250*\zeta_3^A*u**3 + 200*\zeta_3^A*u**2 - 50*\zeta_3^A*u + 525*\zeta_3^V*u**4 - 525*\zeta_3^V*u**3/2 - 525*\zeta_3^V*u**2 + 735*\zeta_3^V*u/2 - 105*\zeta_3^V/2 + 3*a_1^\parallel*u**3 - 6*a_1^\parallel*u**2 + 3*a_1^\parallel*u + 15*a_2^\parallel*u**4 - 75*a_2^\parallel*u**3/2 + 30*a_2^\parallel*u**2 - 15*a_2^\parallel*u/2

# %%
nsimplify(6.*(1.-2.*u)*(1.+a1p*(2.*u-1.)+(a2p/4.+5./3.*z3a*(1.-3./16.*w10a)+35./4.*z3v)*(5.*pow(2.*u-1.,2.)-1.))+6.*u*(1.-u)*(2.*a1p*u+(a2p/4.+5./3.*z3a*(1.-3./16.*w10a)+35./4.*z3v)*(20.*u*(2.*u-1.)))+18.*dtp*(1.-2.*u)-12.*dtm)
# Out:
# 18*\tilde{\delta}_+*(1 - 2*u) - 12*\tilde{\delta}_- + 6*u*(1 - u)*(2*a_1^\parallel*u + 20*u*(2*u - 1)*(5*\zeta_3^A*(1 - 3*\omega_{1,0}^A/16)/3 + 35*\zeta_3^V/4 + a_2^\parallel/4)) + (6 - 12*u)*(a_1^\parallel*(2*u - 1) + (20*(u - 1/2)**2 - 1)*(5*\zeta_3^A*(1 - 3*\omega_{1,0}^A/16)/3 + 35*\zeta_3^V/4 + a_2^\parallel/4) + 1)

# %%
simplify(diff(6*(ubar*ln(ubar) - u*ln(u)), u))
# Out:
# -6*log(u) - 6*log(1 - u) - 12

# %%
A0, A1, A2, V, T1, T2, T3, xi_par, xi_perp = symbols("A_0 A_1 A_2 V T_1 T_2 T_3 \\xi_{\\parallel} \\xi_{\\perp}", real=True)

# %%
s = symbols('s', positive=True)
L_b = symbols('L_b', real=True)
f_87 = nsimplify(4.*pi**2/27.*(2.+s)/pow(1.-s,4.)-4./9.*(11.-16.*s+8.*s*s)/(1.-s)/(1.-s)
	-8./9.*sqrt(s)*sqrt(4.-s)/pow(1.-s,3.)*(9.-5.*s+2.*s*s)*asin(sqrt(s)/2.)
	-16./3.*(2.+s)/pow(1.-s,4.)*pow(asin(sqrt(s)/2.),2.)
	-8.*s/9./(1.-s)*log(s)-32./9.*L_b-I*8./9.*pi)

# %%
simplify(series(f_87, s, 1, 2))
# Out:
# -8*I*pi/9 + 148*sqrt(3)*pi/405 - 94/27 + s - 58*sqrt(3)*pi*s/405 - 32*L_b/9 + O((s - 1)**2, (s, 1))

# %%
f_89 = nsimplify(-8.*pi**2/27.*(4.-s)/pow(1.-s,4.)+8./9.*(5.-2.*s)/(1.-s)/(1.-s)+16./9.*sqrt(4.-s)/sqrt(s)/pow(1.-s,3.)*(4.+3.*s-s*s)*asin(sqrt(s)/2.)+32./3.*(4.-s)/pow(1.-s,4.)*pow(asin(sqrt(s)/2.),2.)+16./9./(1.-s)*log(s))

# %%
simplify(series(f_89, s, 1, 2))
# Out:
# 16*sqrt(3)*pi/45 - 128/27 + 2*s - 28*sqrt(3)*pi*s/135 + O((s - 1)**2, (s, 1))
